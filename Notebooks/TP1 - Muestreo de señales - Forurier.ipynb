# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 1
# #### Oscar Maffei
#
# ***
# ## Muestreo de señales - Fourier

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Se busca realizar una librería en Python que nos permita obtener $N$ muestras de las siguientes señales de período $T_0=1/f_0$, muestreadas a una frecuencia $f_s$ :
#
# </div>

# %% [markdown]
# + **Senoidal**
#
# > $s(k)=A_0.sin((2\pi.f_0 + \phi_0).k/f_s),\space\space \forall k \in \Bbb{Z} \wedge k \in (0, N-1)$
#
# + __Ruido__ incorrelado de distribución Gaussiana y parámetros $\mu$ y $\sigma^2$
#
# ***
#
# + (Opcional) __Cuadrada__ con ciclo de actividad $d \in (0,1)$
#
# > $s(k)=A_0,\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=-A_0,\space \forall k \in (N.d, N-1)$
#
# + (Opcional) __Triangular__ con punto de simetría $d \in (0,1)$ y coeficientes $a_{ij} \in \Bbb{R}$
#
# > $s(k)=a_{11}.k/f_s+a_{12},\space\space \forall k \in (0, N.d ]$
#
# > $s(k)=a_{21}.k/f_s+a_{22},\space \forall k \in (N.d, N-1)$

# %% [markdown]
# Es decir que se podría invocar la señal que genere la senoidal de la siguiente manera:

# %%
def generador_senoidal (fs, f0, N, a0=1, p0=0):
    """ 
    
    brief:  Generador de señales senoidal, con argumentos
    
    fs:     frecuencia de muestreo de la señal [Hz]
    N:      cantidad de muestras de la señal a generar
    f0:     frecuencia de la senoidal [Hz]
    a0:     amplitud pico de la señal [V]
    p0:     fase de la señal sinusoidal [rad]
    
    como resultado la señal devuelve:
    
    signal: senoidal evaluada en cada instante 
    tt:     base de tiempo de la señal
    """    

    # comienzo de la función

    ts=1/fs
    
    #Genero el eje de abcisas
    tt = np.linspace(0, (N-1)*ts, N).flatten()
    
    #genero el eje de ordenadas de N muestras
    
    signal=a0* np.sin(f0 * 2.0 *np.pi*x + p0)
    
    # fin de la función
    
    return tt, signal

# %% [markdown]
# a) Genere las gráficas asociadas a las siguientes señales de ejemplo para corroborar el correcto funcionamiento de las funciones. Para la presentación de las mismas, tome como referencia la presentación de la siguiente señal respecto a:
#
# * etiquetas indicando cada eje con sus respectivas unidades
# * leyendas indicando cada trazo o color qué representa
# * título de la figura que explique lo que se pretende visualizar
#
#
# <img src="./fig_ejemplo.svg" align="center" width="100%" />
# <img src="./fig_ejemplo2.svg" align="center" width="70%" />

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Insertar aquí el código para inicializar tu notebook
########################################################
import siggen as sg
import instruments as inst

# %%
# NO modifiques este bloque
############################

N  = 1000 # muestras
fs = 1000 # Hz

# %%
##################
# a.1) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = 10   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################
t,s1 = sg.Senoidal(a0,f0,p0,N,fs)
inst.ShowSig(t,s1,'Señal: Senoidal f0=10Hz')

# %% [markdown]
# ¿Podría inferir la frecuencia de la senoidal a.1 a partir de su representación temporal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Se puede inferir la frecuencia de la señal senoidal contando la cantidad de ciclos en un intervalo de tiempo. Es necesario, sin embargo, poder representar al menos medio ciclo.
# </div>

# %%
##################
# a.2) Senoidal #
#################

a0 = 1 # Volts
p0 = 0 # radianes
f0 = fs/2   # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################
t,s2 = sg.Senoidal(a0,f0,p0,N,fs)
inst.ShowSig(t,s2,'Señal Senoidal f0=fs/2')

# %%
##################
# a.3) Senoidal #
#################

a0 = 1       # Volts
p0 = np.pi/2 # radianes
f0 = fs/2    # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################
t,s3 = sg.Senoidal(a0,f0,p0,N,fs)
inst.ShowSig(t,s3,'Señal: Senoidal f0=fs/2 p0=pi/2')

# %% [markdown]
# ¿Y para los casos **a.2** y **a.3** podría conocer los parámetros de la senoidal?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> En el caso a.3 se puede inferir la frecuencia de la señal por medio de su representación temporal, en la a.2 no.
# </div>

# %% [markdown]
# ¿A qué se debe?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Cuando la frecuencia de la señal está en el límite de Nyquist aún se pueden tomar dos muestras por ciclo y determinar la frecuencia de la señal pero la amplitud muestreada dependerá de la fase inicial. En el caso de ser pi/2 se observa que las muestras obtenidas coinciden con el pico máximo de la señal. Mientras que para n * pi coinciden con los cruces por cero y no proporcionan información útil.
# </div>

# %%
##################
# a.4) Senoidal #
#################

a0 = 1        # Volts
p0 = 0        # radianes
f0 = fs+10    # Hz

# Insertar aquí el código para generar y visualizar la señal
##############################################################
t,s4 = sg.Senoidal(a0,f0,p0,N,fs)
inst.ShowSig(t,s4,'Señal: Senoidal f0=fs+10')

# %% [markdown]
# ¿Es posible diferenciar **a.1** de **a.4** a partir de las gráficas?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> No se pueden diferenciar las señales en el caso a.1 y el a.4.
# </div>

# %% [markdown]
# ¿En caso que no, qué solución podría implementar para evitar dicha ambigüedad?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Una solución posible es elegir correctamente la fs e implementar un filtro anti alias a la entrada.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.a)</b> (Opcional) Implemente un algoritmo que calcule la transformada discreta de Fourier (DFT). Utilice las funciones generadoras de señales de 1) para evaluar y ejemplificar su funcionamiento.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2.b)</b> (Opcional) Compare el tiempo de ejecución de la DFT implementada en con la **FFT** (implementada en **scipy.signal**) en función del tamaño de la señal N. Grafique el tiempo de ejecución de ambos casos en función de N.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Utilice el módulo **timeit** para medir el tiempo transcurrido.
# </div>

# %%
import time

the_start = time.time()
print("hello")
the_end = time.time()
print(the_start - the_end)
# Out:
# hello
# 0.0008358189988939557

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
from pandas import DataFrame
from IPython.display import HTML

#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['--'], 
                   ['0.0010023117065429688'], # <-- acá debería haber numeritos :)
                   ['0.002506732940673828'], # <-- acá debería haber numeritos :)
                   ['0.011064767837524414'], # <-- acá debería haber numeritos :)
                   ['0.04411816596984863'], # <-- acá debería haber numeritos :)
                   ['0.15555858612060547'], # <-- acá debería haber numeritos :)
                   ['0.6406474113464355'], # <-- acá debería haber numeritos :)
                   ['2.5745832920074463'], # <-- acá debería haber numeritos :)
                   ['10.33392596244812']  # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['tiempo transcurrido (s)'],
               index=['Tamaño de la señal N', 
                      16, 
                      32, 
                      64, 
                      128,
                      256,
                      512,
                      1024,
                      2048
                     ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tiempo transcurrido (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tamaño de la señal N</th>
#       <td>--</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.0010023117065429688</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>0.002506732940673828</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>0.011064767837524414</td>
#     </tr>
#     <tr>
#       <th>128</th>
#       <td>0.04411816596984863</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>0.15555858612060547</td>
#     </tr>
#     <tr>
#       <th>512</th>
#       <td>0.6406474113464355</td>
#     </tr>
#     <tr>
#       <th>1024</th>
#       <td>2.5745832920074463</td>
#     </tr>
#     <tr>
#       <th>2048</th>
#       <td>10.33392596244812</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.a)</b> Verifique el efecto del leakage para una senoidal de $f_0 = f_S/4 + f_D$ siendo $f_D = (0.01,\, 0.25,\, 0.5)$, es decir una frecuencia de desintonía respecto al bin $f_S/4$.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>¡Atención!:</b> Completá la siguiente tabla. Podés guardar tus resultados en la lista **tus_resultados**.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$ \lvert X(f_0) \lvert$', '$ \lvert X(f_0+1) \lvert $', '$\sum_{i=F} \lvert X(f_i) \lvert$'], 
                   ['',                        '',                           '$F:f \neq f_0$'], 
                  ['1.0', '2.0232342018925938e-14', '2.0330404026935867e-12'], # <-- acá debería haber numeritos :)
                  ['0.9998335450382972', '0.010101383898823976', '0.25354911926315604'], # <-- acá debería haber numeritos :)
                  ['0.8996093025909391', '0.3008128277625503', '5.608576601240946'], # <-- acá debería haber numeritos :)
                  ['0.6366176779711066', '0.636623961192577', '8.564476582984877']  # <-- acá debería haber numeritos :)
                 ]
df = DataFrame(tus_resultados, columns=['Frecuencia central', 'Primer adyacente', 'Resto de frecuencias'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '$f_S/4$', 
                      '$f_S/4+0.01$', 
                      '$f_S/4+0.25$', 
                      '$f_S/4+0.5$'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Frecuencia central</th>
#       <th>Primer adyacente</th>
#       <th>Resto de frecuencias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$ \lvert X(f_0) \lvert$</td>
#       <td>$ \lvert X(f_0+1) \lvert $</td>
#       <td>$\sum_{i=F} \lvert X(f_i) \lvert$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$F:f \neq f_0$</td>
#     </tr>
#     <tr>
#       <th>$f_S/4$</th>
#       <td>1.0</td>
#       <td>2.0232342018925938e-14</td>
#       <td>2.0330404026935867e-12</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.01$</th>
#       <td>0.9998335450382972</td>
#       <td>0.010101383898823976</td>
#       <td>0.25354911926315604</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.25$</th>
#       <td>0.8996093025909391</td>
#       <td>0.3008128277625503</td>
#       <td>5.608576601240946</td>
#     </tr>
#     <tr>
#       <th>$f_S/4+0.5$</th>
#       <td>0.6366176779711066</td>
#       <td>0.636623961192577</td>
#       <td>8.564476582984877</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3.b)</b> Verifique qué ocurre si a la señal se le agregan ceros para prolongar su duración. Es decir si la señal tiene N muestras, agregue $M_j$ ceros siendo $M_j = ( \frac{N}{10},\, N,\, 10N)$.
# </div>

# %%
    s=[]
    t,sc=sg.Senoidal(1,250,0,N,fs)
    t,susb=sg.Senoidal(0.5,251,0,N,fs)
    t,slsb=sg.Senoidal(0.5,249,0,N,fs)
    
    s=sc+susb+slsb
    
    inst.ShowSig(t,s)
    fstart=245
    fstop=255
    
    f,f1=inst.ShowFFT(s,N,fs,1,"Señal Original",fstart,fstop)
    
    n=100
    z=np.zeros(n)
    s1=np.append(s,z)
    f,f2=inst.ShowFFT(s1,N+n,fs,1,"Zero Padding N/10",fstart,fstop)
    
    n=1000
    z=np.zeros(n)
    s1=np.append(s,z)
    f,f2=inst.ShowFFT(s1,N+n,fs,1,"Zero Padding N",fstart,fstop)
    
    n=11000
    z=np.zeros(n)
    s1=np.append(s,z)
    f,f2=inst.ShowFFT(s1,N+n,fs,1,"Zero Padding 10N",fstart,fstop)
    
    t,sc=sg.Senoidal(1,250,0,N*10,fs)
    t,susb=sg.Senoidal(0.5,251,0,N*10,fs)
    t,slsb=sg.Senoidal(0.5,249,0,N*10,fs)
    
    s=sc+susb+slsb
    f,f2=inst.ShowFFT(s,N*10,fs,1,"Señal con N + 10*N muestras",fstart,fstop)

# %% [markdown]
# **3.c)** ¿Ha variado la resolución espectral en los casos de 3.b?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> La resolución espectral varia con el agregado de ceros.
# </div>

# %% [markdown]
# **3.d)** ¿Cuál es el efecto que se produce en cada caso? Esta técnica se conoce como Zero padding.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> A medida que aumenta el numero de zeros se aprecia como aumenta la resolución espectral. Sin embargo la técnica de zero padding no aumenta la cantidad de información de la señal muestreada sino que al agregar más puntos mejora la interpolación de la FFT. En la última figura se aprecia la diferencia con la misma onda pero tomando 10N muestras.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b>
# Para cada señal propuesta complete los valores que se indican en las siguientes consignas.
# </div>

# %% [markdown]
# + En la tabla de resultados de cada inciso, en la fila indicada con **predicción** responda conceptualmente qué contenido espectral debería obtener tras evaluar su FFT (sin realizar ninguna simulación).
# + Calcule su espectro y discuta la predicción con los resultados obtenidos de la **simulación**. Intente discutir las diferencias si las hubiera en las respuestas de cada inciso.
# + Preste especial atención en su discusión a:
#   * La energía total de la señal
#   * La energía del tono en particular
#   * La localización del tono en el espectro
# + Siga las indicaciones particulares para cada señal.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Las siguientes señales pueden generarse a partir de una senoidal *patrón* siguiendo las consignas de la derecha.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./1.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">Senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1', '1', '9'], # <-- completar acá
                  ['', '', ''], 
                  ['1.0000000000000004', '1.0000000000000004', '9']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1</td>
#       <td>1</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>1.0000000000000004</td>
#       <td>1.0000000000000004</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./2.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">**1 solo ciclo** de la misma senoidal
# 				de **energía normalizada** y frecuencia $f_0 = 9 \cdot f_S/N$. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1/9', '1/9', '9'], # <-- completar acá
                  ['', '', ''], 
                  ['0.11111094830105504', '0.012345643314521195', '8']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1/9</td>
#       <td>1/9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.11111094830105504</td>
#       <td>0.012345643314521195</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observe el resultado y compare sus resultados con el punto anterior. ¿Qué ha cambiado? ¿Cuánto vale la energía de un solo ciclo de senoidal respecto al caso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> La energía vale ahora 1/9 de la energia en el caso anterior como era esperado, sin embargo la energía en fo difiere de lo predicho. Tambien se aprecia un corrimiento del maximo.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./3.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">1 solo ciclo de la misma senoidal
# 				de energía normalizada y frecuencia $f_0 = 9 \cdot f_S/N$ **pero demorado un tiempo igual a dos ciclos**. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1/9', '1/9', '9'], # <-- completar acá
                  ['', '', ''], 
                  ['0.11111113419864978', '0.012345684220084101', '8']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1/9</td>
#       <td>1/9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.11111113419864978</td>
#       <td>0.012345684220084101</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# En este caso, ¿Qué ha cambiado respecto al anterior? ¿Cómo se manifiesta en el dominio frecuencial?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Un desplazamiento temporal no genera cambios en es espectro ni en la energía de la señal.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./4.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">1 solo ciclo de la misma senoidal utilizada hasta ahora, y otro ciclo de idénticas características pero de $f_1 = 8 \cdot f_S/N$ y demorado aproximadamente como se observa a la izquierda. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1/9+1/8', '1/9', '8'], # <-- completar acá
                  ['', '', ''], 
                  ['0.2361109501968798', '0.049208909882560034', '6']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1/9+1/8</td>
#       <td>1/9</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.2361109501968798</td>
#       <td>0.049208909882560034</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Puede localizar ambas componentes en este espectro? ¿Cómo lo haría?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> En es espectro se aprecian dos picos que corresponden a las máximas energias.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./5.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">Idéntico al caso anterior salvo que se invierte la ocurrencia de las señales. </span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1/8+1/9', '1/8', '8'], # <-- completar acá
                  ['', '', ''], 
                  ['0.2361109501968798', '0.049151157062324737', '6']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1/8+1/9</td>
#       <td>1/8</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.2361109501968798</td>
#       <td>0.049151157062324737</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿ha cambiado el espectro respecto al caso anterior? ¿Si solo dispone del espectro, puede decir cuál ha ocurrido antes? ¿Resulta útil el análisis de espectral mediante la transformada de Fourier en este caso?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Es espectro no cambió a pesar de haber invertido el orden temporal de las señales. En este caso el analisis de la TF no es util ya que no brinda información sobre que suceso ocurrió primero y cuál después.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./6.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">Arme una señal como la que se muestra a la izquierda, concatenando 3 ciclos de $f_0 = 9 \cdot f_S/N$.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['3/9', '3/9', '9'], # <-- completar acá
                  ['', '', ''], 
                  ['0.33333254129370843', '0.11111058540128561', '9']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>3/9</td>
#       <td>3/9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.33333254129370843</td>
#       <td>0.11111058540128561</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con la señal donde los 9 ciclos estaban presentes? ¿Y respecto a la que solo había 1 ciclo?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> La componente en $f_0$ tiene 1/9 de la energia del caso en que los nueve ciclos estaban presentes y 9 veces más que en el caso de un solo ciclo.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./7.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">Idem anterior, pero cada ciclo con diferente amplitud.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['1/81+1/9+1/27', '', '9'], # <-- completar acá
                  ['', '', ''], 
                  ['0.12482835095846304', '0.025757905256031808', '9']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>1/81+1/9+1/27</td>
#       <td></td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.12482835095846304</td>
#       <td>0.025757905256031808</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> En este caso tiene casi 1/5 de la energía total mientras que en el caso anterior tenía 1/3.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./8.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">Idem anterior, pero repetida 3 veces.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['3*ant', '9*ant', '9'], # <-- completar acá
                  ['', '', ''], 
                  ['0.37448505439946883', '0.23176624058929893', '9']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>3*ant</td>
#       <td>9*ant</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.37448505439946883</td>
#       <td>0.23176624058929893</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el inciso anterior? ¿Y respecto al que estaban los 9 ciclos presentes pero con la misma amplitud?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> En $f_0$ tiene nueve veces la energia del caso anterior pero apenas un 23% del caso en el que estaban los nueve ciclos.
# </div>

# %% [markdown]
# <table width="80%" cellpadding="7" cellspacing="0">
# 	<col width="50%">
# 	<col width="50%">
# 	<tbody>
# 		<tr valign="top">
# 			<td width="296" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding: 0cm">
# 				<p>
#                     <img src="./9.png" align="left" width="100%" />
#                 </p>
# 			</td>
# 			<td width="267" style="border-top: none; border-bottom: none; border-left: none; border-right: none; padding-top: 0cm; padding-bottom: 0cm; padding-left: 0.19cm; padding-right: 0cm">
# 				<p style="margin-bottom: 0cm"><span lang="es-AR">En este caso genere un ciclo de $f_0 = 9 \cdot f_S/N$, y seguido otro ciclo pero desfasado $\pi$ radianes.</span></font>
# 				</p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$', '$ \lvert X(f_0) \rvert ^2 $', '$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $'], 
                   ['',                                     '',                           '$f \in [0:f_S/2]$'], 
                  ['', '', ''], 
                  ['2/9', '2/27', ''], # <-- completar acá
                  ['', '', ''], 
                  ['0.22222210826508773', '1.2144740353350894e-05', '5']  # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía en $f_0$', 'Máximo de Energía'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '', 
                      'predicción', 
                      '', 
                      'simulación'])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía en $f_0$</th>
#       <th>Máximo de Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert X(f) \rvert ^2$</td>
#       <td>$ \lvert X(f_0) \rvert ^2 $</td>
#       <td>$ \mathop{arg\ max}_f \{\lvert X(f) \rvert ^2\} $</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td>$f \in [0:f_S/2]$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>predicción</th>
#       <td>2/9</td>
#       <td>2/27</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>simulación</th>
#       <td>0.22222210826508773</td>
#       <td>1.2144740353350894e-05</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ¿Qué energía tiene la componente $f_0$ en el espectro en comparación con el que estaba un solo ciclo presente?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Practicamente no tiene energía porque coincide con un minimo en la FFT.
# </div>

# %% [markdown]
# Luego de realizar la experimentación y observando los resultados obtenidos discuta si es fiable o no medir en el dominio de Fourier, por medio de la FFT los siguientes aspectos de una señal:
#
#     • Energía
#     • Contenido espectral
#     • Energía de un determinado ancho de banda o componente espectral
#     • Localización temporal de un determinado componente espectral.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> No hay problemas en la determinación de la energía. El contenido espectral se representara mejor o peor dependiendo de la cantidad de puntos con la que trabaje la FFT.Determinar la energía de un determinado ancho de banda no presenta mayores dificultades. La FFT no resulta util para determinar eventos temporales.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b>
# Simule el efecto de cuantizar una señal continua en el tiempo mediante un conversor analógico digital (ADC).
# </div>

# %% [markdown]
# Para ello analice señales determinísticas, por ejemplo una senoidal de **energía normalizada** y frecuencia $f_0$, y otras que varíen de forma más aleatoria y por lo tanto, representativa de una señal real, por ejemplo añadiendo ruido. Es decir que la señal *real* simulada será
#
# $$s_R = s + n$$
#
# donde la señal $n$ debe tener una energía de $1/10$.
#
# Puede simular una señal continua (aproximadamente para los fines prácticos), mediante una señal muestreada a una $f^1_S$ muy alta en comparación con las $f_S$  que quiere estudiar, y un tipo de dato de doble precisión (double o float de 64 bits). De esta manera se asegura una grilla de cuantización (en tiempo y amplitud) mucho más densa que la que se va a simular. Se pide cuantizar a palabras de 4, 8 y 16 bits, obteniendo
#
# $$ s_Q = \mathop{Q}_i \{s_R\} \quad i \in (4, 8, 16) $$
#
# Siendo $\mathop{Q}_i$ la función **no lineal** responsable de la cuantización a *i-* bits de la señal real $s_R$. Describa el ruido de cuantización
#
# $$ e = s_Q - s_R$$
#
# para las 3 situaciones antedichas siguiendo las siguientes consignas.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.a)</b>
# La señal temporal $e$ y su espectro $E$.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ ['$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$', '$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$' ], 
                   ['',                                             '',                                             ''                              ], 
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Energía total', 'Energía total Q', 'Energía total $e$'],
               index=['$f_0$ \ expr. matemática', 
                      '', 
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energía total</th>
#       <th>Energía total Q</th>
#       <th>Energía total $e$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>$f_0$ \ expr. matemática</th>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_R(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert S_Q(f) \rvert ^2$</td>
#       <td>$\sum_{f=0}^{f_S/2} \lvert e(f) \rvert ^2$</td>
#     </tr>
#     <tr>
#       <th></th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.b)</b> El histograma de la señal $e_i$ para cada tamaño de palabra.
# </div>

# %%
#####################################
# Tu simulación que genere gráficas #
#####################################

# %% [markdown]
# ¿Qué información podemos obtener de esta forma de analizar la señal $e_i$?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.c)</b> Una descripción de la señal $e_i$, por medio del **valor medio**, su valor **RMS** y su energía **energía**
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Valor medio', 'RMS', 'Energía'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor medio</th>
#       <th>RMS</th>
#       <th>Energía</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5.d)</b> Una descripción **estadística** de la señal $e_i$, por medio de su **media**, su **desvío estándard** y su energía **varianza**.
# </div>

# %%
#######################################
# Tu simulación que genere resultados #
#######################################

tus_resultados = [ 
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                   ['', '', ''], # <-- completar acá
                 ]
df = DataFrame(tus_resultados, columns=['Media', 'Desvío estándard', 'Varianza'],
               index=[
                      '4 bits', 
                      '8 bits', 
                      '16 bits'
                      ])
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Media</th>
#       <th>Desvío estándard</th>
#       <th>Varianza</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16 bits</th>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Discutir las similitudes y diferencias con los parámetros calculados en **c)** y **d)**.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>
